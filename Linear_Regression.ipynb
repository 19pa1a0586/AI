# %% [markdown]
# <a href="https://colab.research.google.com/github/19pa1a0586/AI/blob/master/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cv=pd.read_csv("COVID19_line_list_data.csv")
cv
# Out:
#         id  ...                                               link
# 0        1  ...  http://wjw.sz.gov.cn/wzx/202001/t20200120_1898...
# 1        2  ...  https://www.weibo.com/2372649470/IqogQhgfa?fro...
# 2        3  ...  http://www.zjwjw.gov.cn/art/2020/1/21/art_1202...
# 3        4  ...        https://m.weibo.cn/status/4463235401268457?
# 4        5  ...        https://m.weibo.cn/status/4463235401268457?
# ...    ...  ...                                                ...
# 1080  1081  ...  https://www.thejakartapost.com/news/2020/02/25...
# 1081  1082  ...  https://www.foxnews.com/health/afghanistan-fir...
# 1082  1083  ...  https://www.scmp.com/news/china/society/articl...
# 1083  1084  ...  https://www.reuters.com/article/us-croatia-cor...
# 1084  1085  ...  https://www.reuters.com/article/uk-switzerland...
#
# [1085 rows x 21 columns]

# %%
cv.columns
# Out:
# Index(['id', 'case_in_country', 'reporting date', 'Unnamed: 3', 'summary',
#        'location', 'country', 'gender', 'age', 'symptom_onset',
#        'If_onset_approximated', 'hosp_visit_date', 'exposure_start',
#        'exposure_end', 'visiting Wuhan', 'from Wuhan', 'death', 'recovered',
#        'symptom', 'source', 'link'],
#       dtype='object')
